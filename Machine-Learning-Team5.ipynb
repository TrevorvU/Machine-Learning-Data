# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from scipy import stats #nodig om outliers te verwijderen




#df = pd.read_csv('Case_PRB.csv')
#a_df.head()

attributes = ["location", "total_cases", "new_cases"]
#names kan je ook weglaten vooral als je veel kolommen hebt - 
df = pd.read_csv('Case_PRB.csv',names=attributes,header=0,low_memory=False)
df.columns = attributes
#Met head print je de content van je data
#df.head(5)
#df.dtypes
#df.describe()
#ook eeen onderdeel van preprocessing is het verwijderen van outliers 

#Histogram hiermee kan je de verdeling van je data zien
# n_bins = 6 #aantal dat omhoogsteekt
# fig, axs = plt.subplots(2, 2)
# axs[0, 0].hist(df['total_cases'], bins = n_bins)
# axs[0, 0].set_title('Total Cases')
# axs[0, 1].hist(df['total_cases'], bins = n_bins)
# axs[0, 1].set_title('Total Cases')
# axs[1, 0].hist(df['total_cases'], bins = n_bins)
# axs[1, 0].set_title('Total Cases')
# axs[1, 1].hist(df['total_cases'], bins = n_bins)
# axs[1, 1].set_title('Total Cases')
#https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html
#https://matplotlib.org/stable/gallery/animation/animated_histogram.html#sphx-glr-gallery-animation-animated-histogram-py
#https://towardsdatascience.com/random-forest-in-python-24d0893d51c0

# fig.tight_layout(pad=1.0) #rechtsboven kan je de specifieke afbeelding saven
df.isna().sum()
#BoxPlots elke box heeft zijn eigen klasse
#eindigt op 19:44 van Werksessie 1
# Out:
# location       9735
# total_cases     914
# new_cases      6963
# dtype: int64

# %%
#boxplots #code is still not functioning ended at 20:00
#Welke waarden horen er eigenlijk niet tussen of is minder relevant
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats #Deze gebruik je om outliers te verwijderen
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing

# attributes = ["location", "total_cases", "new_cases"]
# attributes = ["population_density", "total_cases", "new_cases", "aged_65_older"]
# df = pd.read_csv('Case_PRB.csv',low_memory=False)
# df.columns = attributes
# df.fillna(999, inplace=True)
# df.replace([np.inf, -np.inf], np.nan, inplace=True)
# df.dropna()
# df.dropna(subset=["population_density"], inplace= True) 
# df.dropna(subset=["total_cases"], inplace= True) 
# df.dropna(subset=["new_cases"], inplace= True) 
# df.dropna(subset=["aged_65_older"], inplace= True) 
# df = df.reset_index(drop = True)
# df.dtypes
# print(df)
# lab_enc = preprocessing.LabelEncoder()
# encoded = lab_enc.fit_transform(df)
# fig, axs = plt.subplots(2, 2)
# fn = ["total_cases", "new_cases", "population_density", "extreme_poverty"]
# cn = ["development_index", "location", "hospital_beds_per_thousand"]
# sns.boxplot(x = "location", y = "new_cases", data = df, ax = axs[0,0])
# sns.boxplot(x = "location", y = "new_cases", data = df, ax = axs[0,1])
# sns.boxplot(x = "location", y = "new_cases", data = df, ax = axs[1,0])
# sns.boxplot(x = "location", y = "new_cases", data = df, ax = axs[1,1])
# #pad = padding
# fig.tight_layout(pad=1.0)

#hiermee kan je zien hoeveel dingen van elkaar afwijken
#je wilt eigenlijk dat bepaalde waarden zo laag of zo hoog mogelijk zijn
#het is van hoe erg de 1 stijgt, hoeveel stijgt de andere waarde mee
#Ook moet de preprocessingdata gelijk qua WAARDE zijn aan elkaar
# correlation = df.corr()
# sns.heatmap(correlation, annot= True, square= True)
#ook heb je een train test validation split

#dit kan fungeren als een test in veel data is er bijvoorbeeld veel outliers train en testdata moet gelijk zijn
#of meters en centimeters, dus de manier waarop de variabelen gemeten zijn, moet gelijk zijn
#stratify= df['total_cases'] stratify is nodig voor de classen/waardes gelijk blijven over deze set
# df_cont = df[['total_cases', 'population_density', 'new_cases', 'aged_65_older']]
# df_cont_remove_nan = df_cont.dropna()
# df_cont_fillna_ffil = df_cont.fillna(0)
# train, test = train_test_split(df_cont_fillna_ffil, test_size= 0.33, random_state=42)
# # print(test)
# train.groupby('total_cases').size()
# #vanaf 30:00 
# #De raw data is de features and variables die je gebruikt om te trainen 
# x_train  = train[['total_cases', 'new_cases', 'population_density', 'aged_65_older']]
# y_train  = train['total_cases']
# x_test  = test[['total_cases', 'new_cases', 'population_density', 'aged_65_older']]
# y_test = test[['total_cases']]
# x_train
#desciscion tree
#random state hoe random moet het model geïnitieerd worden
#telkens wanneer je een model initieert dan krijg je ook random weights
#bij een nieuw model dan is het verstandig om dezelfde random state te gebruiken voor ongeveer
#dezelfde soor trandomness 
# mod_dt = DecisionTreeClassifier(max_depth=10, random_state=1)
# mod_dt.fit(x_train,y_train)
# prediction = mod_dt.predict(x_test) 

# print('The accurary of the tree is', "{:.3f}".format(metrics.accuracy_score(prediction, y_test)))
# df.describe()

# %%
correlation = df.corr()
sns.heatmap(correlation, annot= True, square= True)
# Out:
# <AxesSubplot:>

# %%
df.isna().sum()
# Out:
# location       9735
# total_cases     914
# new_cases      6963
# dtype: int64

# %%
df = pd.read_csv('Case_PRB.csv', low_memory=False)
# df.head()
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  4.903200e+04   48809.000000        48027.000000  4.903200e+04
# mean   1.164479e+05    1539.422770         1523.171677  4.454314e+03
# std    1.203765e+06   13899.994619        13661.787655  4.127713e+04
# min    0.000000e+00   -8261.000000         -552.000000  0.000000e+00
# 25%    7.100000e+01       0.000000            0.714000  1.000000e+00
# 50%    1.176000e+03      11.000000           16.286000  2.300000e+01
# 75%    1.310625e+04     179.000000          185.857000  2.730000e+02
# max    3.756884e+07  387487.000000       328458.286000  1.077508e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  48809.000000         48027.000000             48745.000000
# mean      44.152021            44.189808              2154.172539
# std      370.378116           359.720383              4469.638599
# min    -1918.000000          -232.143000                 0.000000
# ...

# %%
df.isna().sum()
# Out:
# iso_code                             287
# continent                            574
# location                               0
# date                                   0
# total_cases                          636
# new_cases                            859
# new_cases_smoothed                  1641
# total_deaths                         636
# new_deaths                           859
# new_deaths_smoothed                 1641
# total_cases_per_million              923
# new_cases_per_million                923
# new_cases_smoothed_per_million      1706
# total_deaths_per_million             923
# new_deaths_per_million               923
# new_deaths_smoothed_per_million     1706
# new_tests                          31622
# total_tests                        31203
# total_tests_per_thousand           31203
# new_tests_per_thousand             31622
# new_tests_smoothed                 29251
# new_tests_smoothed_per_thousand    29251
# tests_per_case                     30858
# ...

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'tests_per_case', 'positive_rate', 'tests_units', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
# df_cont = df[['new_tests', 'total_tests', 'tests_per_case', 'positive_rate',
# 'population', 'population_density', 'median_age', 'aged_65_older', 'aged_70_older', 'gdp_per_capita']]

df_cont = df[['population', 'human_development_index', 
'new_cases', 'new_deaths', 'gdp_per_capita', 'extreme_poverty', 'total_deaths', 'median_age']]
# df_cont2 = df[['new_deaths', 'gdp_per_capita']]
# df_cont = df[['gdp_per_capita', 'median_age']]
# df_cont = df[['human_development_index', 'median_age']]

# df_cat = df[['continent', 'location', 'date']]

# %%
df_cont_remove_nan = df_cont.dropna()
# df_cont_age_nan = df_cont_age.dropna()
#df_cont_fillna_fill = df_cont.fillna(method='ffill') #hiermee vul je de waardes anders moet je te 
#veel rows wegdoen en dan kan je niet new_tests et cetera bij het model meetrainen
#df_cont_remove_nan.isna().sum()
# df_cont_remove_nan.describe()
#len(df_cont_fillna_fill) #na de dropna van new_tests et cetera zijn er nog ongeveer 17k rows over
#maar als je die new_tests et cetera weghaald dan zijn er nog 42k rows over
#df_cont_remove_nan.isna().sum()
len(df_cont_remove_nan)
df_cont_remove_nan.describe
# Out:
# <bound method NDFrame.describe of        human_development_index  gdp_per_capita  extreme_poverty  total_deaths  \
# 901                      0.785       11803.431              1.1           0.0
# 902                      0.785       11803.431              1.1           0.0
# 903                      0.785       11803.431              1.1           0.0
# 904                      0.785       11803.431              1.1           1.0
# 905                      0.785       11803.431              1.1           1.0
# ...                        ...             ...              ...           ...
# 49089                    0.535        1899.775             21.4         229.0
# 49090                    0.535        1899.775             21.4         229.0
# 49091                    0.535        1899.775             21.4         229.0
# 49092                    0.535        1899.775             21.4         230.0
# 49093                    0.535        1899.775             21.4         230.0
#
# ...

# %%
# fig, ax = plt.subplots(figsize=(10, 10))
# ax.boxplot(df.values, 
# labels = df_cont_age_nan.columns.values)

# # ax[0, 1].boxplot(df_cont_fillna_fill.values, 
# # labels = df_cont_fillna_fill.columns.values)
# plt.show()

# %%
#normalizeren dit doen we zodat alles dezelfde schaal krijgt
df_cont_na_mean_normalized = (df_cont_remove_nan - df_cont_remove_nan.mean())/df_cont_remove_nan.std()

df_cont_na_mean_normalized.head()
# Out:
#      human_development_index  gdp_per_capita  extreme_poverty  total_deaths  \
# 901                 0.483296       -0.305915        -0.578951     -0.227023
# 902                 0.483296       -0.305915        -0.578951     -0.227023
# 903                 0.483296       -0.305915        -0.578951     -0.227023
# 904                 0.483296       -0.305915        -0.578951     -0.226957
# 905                 0.483296       -0.305915        -0.578951     -0.226957
#
#      median_age
# 901    0.797553
# 902    0.797553
# 903    0.797553
# 904    0.797553
# 905    0.797553

# %%
df_cont_na_mean_normalized.describe()
# Out:
#        human_development_index  gdp_per_capita  extreme_poverty  total_deaths  \
# count             2.822300e+04    2.822300e+04     2.822300e+04  2.822300e+04
# mean             -1.320074e-13    2.971203e-14    -7.801758e-14 -1.707546e-15
# std               1.000000e+00    1.000000e+00     1.000000e+00  1.000000e+00
# min              -2.309870e+00   -9.538083e-01    -6.302558e-01 -2.270226e-01
# 25%              -7.869141e-01   -7.846285e-01    -6.097339e-01 -2.268268e-01
# 50%               2.370310e-01   -3.137563e-01    -5.327768e-01 -2.233676e-01
# 75%               7.425228e-01    4.506091e-01     2.932299e-01 -1.888407e-01
# max               1.572048e+00    4.507498e+00     3.345863e+00  1.379069e+01
#
#          median_age
# count  2.822300e+04
# mean   2.695414e-13
# std    1.000000e+00
# min   -1.677191e+00
# 25%   -1.028787e+00
# 50%   -1.426339e-01
# 75%    9.164270e-01
# max    1.867420e+00

# %%
# sns.pairplot(df_cont_na_mean_normalized) #this will take 6,5 minutes if you run this 28:00 #add another argument or paramater to 
#decrease the time

# %%
fig, ax = plt.subplots(figsize=(16,7))
 #de oranje lijn geeft de mean aan
ax.boxplot(
    df_cont_na_mean_normalized.values,
    labels = df_cont_na_mean_normalized.columns.values
)

plt.show()

# %%
df_cont_na_mean_normalized.describe()
Q1 = df_cont_na_mean_normalized.quantile(0.25)
Q3 = df_cont_na_mean_normalized.quantile(0.75) 
#De IQR methodes wordt gebruikt om outliers te verwijderen
IQR = Q3 - Q1

IQR
treshold = 1.5
df_cont_na_mean_normalized_outliers = df_cont_na_mean_normalized[~((df_cont_na_mean_normalized < 
(Q1 - treshold *IQR))|(df_cont_na_mean_normalized > (Q3 + treshold *IQR))).any(axis=1)]

fig, ax = plt.subplots(figsize=(20,7))
 #de oranje lijn geeft de mean aan
ax.boxplot(
    df_cont_na_mean_normalized_outliers.values,
    labels = df_cont_na_mean_normalized_outliers.columns.values
)

plt.show()
df_cont_na_mean_normalized.describe()
# Out:
#        human_development_index  gdp_per_capita  extreme_poverty  total_deaths  \
# count             2.822300e+04    2.822300e+04     2.822300e+04  2.822300e+04
# mean             -1.320074e-13    2.971203e-14    -7.801758e-14 -1.707546e-15
# std               1.000000e+00    1.000000e+00     1.000000e+00  1.000000e+00
# min              -2.309870e+00   -9.538083e-01    -6.302558e-01 -2.270226e-01
# 25%              -7.869141e-01   -7.846285e-01    -6.097339e-01 -2.268268e-01
# 50%               2.370310e-01   -3.137563e-01    -5.327768e-01 -2.233676e-01
# 75%               7.425228e-01    4.506091e-01     2.932299e-01 -1.888407e-01
# max               1.572048e+00    4.507498e+00     3.345863e+00  1.379069e+01
#
#          median_age
# count  2.822300e+04
# mean   2.695414e-13
# std    1.000000e+00
# min   -1.677191e+00
# 25%   -1.028787e+00
# 50%   -1.426339e-01
# 75%    9.164270e-01
# max    1.867420e+00

# %%
df_final = pd.merge(df_cont_na_mean_normalized_outliers, df, left_index=True, right_index=True)
df_final.shape
# Out:
# (19824, 46)

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
# import graphviz
from sklearn.metrics import accuracy_score

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.multioutput import MultiOutputRegressor
from sklearn.linear_model import LinearRegression, HuberRegressor, RANSACRegressor, TheilSenRegressor, LogisticRegression
from sklearn.ensemble import RandomForestRegressor
#werkt tegen outliers: HuberRegressor, RANSAC Regression(Meeste outliers verwijderen), 
# Theil Sen Regression
#Eerst beginnen met linear regression
#- K-nearest neighbours - Desiscion trees - Random Forest - Linear/logistic regression - Support vector machines


# X = df_cont_na_mean_normalized.iloc[:,:-1] # the right 1
X = df_cont_na_mean_normalized_outliers.iloc[:,:-1] # the right 1


# y = df_cont_na_mean_normalized.iloc[: , -1] #the right 1
y = df_cont_na_mean_normalized_outliers.iloc[: , -1] #the right 1

# labelEncoder_y = LabelEncoder()
# y[:, 6] = labelEncoder_y.fit_transform(y[:, 6])
# y[:, 7] = labelEncoder_y.fit_transform(y[:, 7])
# y[:, 8] = labelEncoder_y.fit_transform(y[:, 8])


# Z = pd.DataFrame(y)
# Z
# oneHotEncoder = OneHotEncoder()
# y = oneHotEncoder.fit_transform(y).torray()
# ct = ColumnTransformer([("iso_code", OneHotEncoder(), [7])])
# y = ct.fit_transform(y)
# Z = pd.DataFrame(y)
# Z
# enc = OneHotEncoder(handle_unknown='ignore')
# enc.fit(y)
# enc.transform([['iso_code',1], ['continent', 2], ['location', 3]]).toarray()

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42
)
# df_cont_na_mean_normalized_outliers.describe
correlation = df_cont_na_mean_normalized_outliers.corr()
sns.heatmap(correlation, annot= True, square= True)
# Out:
# <AxesSubplot:>

# %%
# dot_data = tree.export_graphviz(clf, class_names=['0', '1'], out_file=None)
# # graph = graphviz.Source(dot_data)
# graph
#GDP per capita voorspellen
# clf = DecisionTreeClassifier(random_state=0)
# multi_output_clf = MultiOutputRegressor(DecisionTreeClassifier())

# multi_output_clf.fit(X_train, y_train)
# clf = LinearRegression(random_state=0) #misschien new_deaths toevoegen - bijvoorbeeld gpd kan wel invloed hebben op new_deaths
# clf = LinearRegression() #meerdere regression modellen
regressor = RandomForestRegressor()
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# predictions = regressor.predict(X_test)
# plt.scatter(X, y)
# plt.plot(X, regressor.predict(X), color='g')
# plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
# score = accuracy_score(y_test, predictions) #check other accuracy scores
#R square / adjusted R square hoe dicht bij de fitted regressie lijn R^2 = 0 - 100(of 0 en 1) 
# en 100 is goed - Adjusted R square gebruiken in het uiterste geval 
#Mean Square Error(MSE) / Root Mean Square Error(RMSE) absolute "goodness" van de fit
#Mean Absolute Error(MAE )
#En Mean Absolute Error gebruiken
# score = sqrt(mean_squared_error(y_test, regressor.predict(X_test))) #check other accuracy scores
score = sqrt(mean_squared_error(y_test, regressor.predict(X_test))) #check other accuracy scores
print(score) #
# Out:
# 0.0038228251983053107
